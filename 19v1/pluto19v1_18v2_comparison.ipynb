# %%
from pyspark.sql.functions import mean, udf, col, round
from pyspark.sql.types import DoubleType
from pyspark.sql.window import Window
from pyspark.sql.functions import rank, col
import pandas as pd
import numpy as np
import time
import datetime
import matplotlib.pyplot as plt

from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
sc = SparkContext('local')
spark = SparkSession(sc)

# %%
# %matplotlib inline
now = datetime.datetime.now()
print(now)
# os.environ["PYSPARK_PYTHON"]="/anaconda3/bin/python3"
df1 = spark.read.csv('data/pluto_19v1.csv', header=True)
df2 = spark.read.csv('data/pluto_18v2_1.csv', header=True)
# Out:
# 2019-05-29 15:43:46.115576

# %%
list(zip(df1.columns, df2.columns))
# Out:
# [('borough_1', 'borough'),
#  ('block_1', 'block'),
#  ('lot_1', 'lot'),
#  ('cd_1', 'cd'),
#  ('ct2010_1', 'ct2010'),
#  ('cb2010_1', 'cb2010'),
#  ('schooldist_1', 'schooldist'),
#  ('council_1', 'council'),
#  ('zipcode_1', 'zipcode'),
#  ('firecomp_1', 'firecomp'),
#  ('policeprct_1', 'policeprct'),
#  ('healtharea_1', 'healtharea'),
#  ('sanitboro_1', 'sanitboro'),
#  ('sanitsub_1', 'sanitsub'),
#  ('address_1', 'address'),
#  ('zonedist1_1', 'zonedist1'),
#  ('zonedist2_1', 'zonedist2'),
#  ('zonedist3_1', 'zonedist3'),
#  ('zonedist4_1', 'zonedist4'),
#  ('overlay1_1', 'overlay1'),
#  ('overlay2_1', 'overlay2'),
#  ('spdist1_1', 'spdist1'),
#  ('spdist2_1', 'spdist2'),
#  ('spdist3_1', 'spdist3'),
#  ('ltdheight_1', 'ltdheight'),
#  ('splitzone_1', 'splitzone'),
#  ('bldgclass_1', 'bldgclass'),
#  ('landuse_1', 'landuse'),
#  ('easements_1', 'easements'),
#  ('ownertype_1', 'ownertype'),
#  ('ownername_1', 'ownername'),
#  ('lotarea_1', 'lotarea'),
#  ('bldgarea_1', 'bldgarea'),
#  ('comarea_1', 'comarea'),
#  ('resarea_1', 'resarea'),
#  ('officearea_1', 'officearea'),
#  ('retailarea_1', 'retailarea'),
#  ('garagearea_1', 'garagearea'),
#  ('strgearea_1', 'strgearea'),
#  ('factryarea_1', 'factryarea'),
#  ('otherarea_1', 'otherarea'),
#  ('areasource_1', 'areasource'),
#  ('numbldgs_1', 'numbldgs'),
#  ('numfloors_1', 'numfloors'),
#  ('unitsres_1', 'unitsres'),
#  ('unitstotal_1', 'unitstotal'),
#  ('lotfront_1', 'lotfront'),
#  ('lotdepth_1', 'lotdepth'),
#  ('bldgfront_1', 'bldgfront'),
#  ('bldgdepth_1', 'bldgdepth'),
#  ('ext_1', 'ext'),
#  ('proxcode_1', 'proxcode'),
#  ('irrlotcode_1', 'irrlotcode'),
#  ('lottype_1', 'lottype'),
#  ('bsmtcode_1', 'bsmtcode'),
#  ('assessland_1', 'assessland'),
#  ('assesstot_1', 'assesstot'),
#  ('exemptland_1', 'exemptland'),
#  ('exempttot_1', 'exempttot'),
#  ('yearbuilt_1', 'yearbuilt'),
#  ('yearalter1_1', 'yearalter1'),
#  ('yearalter2_1', 'yearalter2'),
#  ('histdist_1', 'histdist'),
#  ('landmark_1', 'landmark'),
#  ('builtfar_1', 'builtfar'),
#  ('residfar_1', 'residfar'),
#  ('commfar_1', 'commfar'),
#  ('facilfar_1', 'facilfar'),
#  ('borocode_1', 'borocode'),
#  ('bbl_1', 'bbl'),
#  ('condono_1', 'condono'),
#  ('tract2010_1', 'tract2010'),
#  ('xcoord_1', 'xcoord'),
#  ('ycoord_1', 'ycoord'),
#  ('zonemap_1', 'zonemap'),
#  ('zmcode_1', 'zmcode'),
#  ('sanborn_1', 'sanborn'),
#  ('taxmap_1', 'taxmap'),
#  ('edesignum_1', 'edesignum'),
#  ('appbbl_1', 'appbbl'),
#  ('appdate_1', 'appdate'),
#  ('mappluto_f_1', 'mappluto_f'),
#  ('plutomapid_1', 'plutomapid'),
#  ('version_1', 'version'),
#  ('sanitdistrict_1', 'sanitdistrict'),
#  ('healthcenterdistrict_1', 'healthcenterdistrict'),
#  ('firm07_flag_1', 'firm07_flag'),
#  ('pfirm15_flag_1', 'pfirm15_flag'),
#  ('rpaddate_1', 'rpaddate'),
#  ('dcasdate_1', 'dcasdate'),
#  ('zoningdate_1', 'zoningdate'),
#  ('landmkdate_1', 'landmkdate'),
#  ('basempdate_1', 'basempdate'),
#  ('masdate_1', 'masdate'),
#  ('polidate_1', 'polidate'),
#  ('edesigdate_1', 'edesigdate')]

# %%
len(df1.schema.names)
# Out:
# 96

# %%
len(df2.schema.names)
# Out:
# 96

# %%
df2.count()
# Out:
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-21-770c88a94be5> in <module>
# ----> 1 df2.count()
#
# /usr/local/spark/python/pyspark/sql/dataframe.py in count(self)
#     520         2
#     521         """
# --> 522         return int(self._jdf.count())
#     523
#     524     @ignore_unicode_prefix
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     334             raise Py4JError(
#     335                 "An error occurred while calling {0}{1}{2}".
# --> 336                 format(target_id, ".", name))
#     337     else:
#     338         type = answer[1]
#
# Py4JError: An error occurred while calling o775.count

# %%
df1.count()
# Out:
# 859930

# %%
df1 = df1.select([col(A).alias(A.lower()) for A in df1.schema.names])
df2 = df2.select([col(A).alias(A.lower()) for A in df2.schema.names])

double_columns = ['bldgarea', 'facilfar','residfar', 'commfar', 
                  'numbldgs', 'numfloors', 'bldgdepth','bldgfront', 
                  'lotdepth', 'lotfront','exemptland', 'exempttot', 
                  'assessland', 'assesstot','builtfar']
cols = df2.columns
df1 = df1.select(cols)
df2 = df2.select(cols)

for A in double_columns: 
    df1 = df1.withColumn(A, round(col(A).cast(DoubleType()), 2))
    df2 = df2.withColumn(A, round(col(A).cast(DoubleType()), 2))
    

df1 = df1.select([col(A).alias(A+'_1') for A in df1.schema.names])

colnames = zip(df1.columns, df2.columns)

df = df2.join(df1, df2['bbl'] == df1['bbl_1'])

# %%
@udf
def compare(col1,col2):
    if col1!=col2:
        return 1
    else:
        return 0
    
access_cols = ['exemptland', 'exempttot', 'assessland', 'assesstot']

@udf #special access column comparison
def compare_a(col1,col2):
    try: 
        if abs(col1 - col2) > 10: 
            return 1
        else: 
            return 0
    except: 
        return 0

# %%
spark.sql('set spark.sql.caseSensitive=true')
for A,B in colnames:
    if B in access_cols:
        df = df.withColumn(B+'%', compare_a(col(A),col(B)))\
               .drop(A,B)
    else:
        df = df.withColumn(B+'%', compare(col(A),col(B)))\
                   .drop(A,B)
        
results = df.select(*[mean(col(A)).alias(A) for A in df.columns])

# %%
start_time = time.time()
results_df = results.toPandas()
elapsed_time = time.time() - start_time

# %%
results_df.iloc[0,:].sort_values(ascending=False)[0:30]
# Out:
# edesigdate%       1.000000
# basempdate%       1.000000
# landmkdate%       1.000000
# zoningdate%       1.000000
# dcasdate%         1.000000
# rpaddate%         1.000000
# condono%          0.999294
# landuse%          0.953318
# appbbl%           0.892796
# plutomapid%       0.892572
# tract2010%        0.887042
# assessland%       0.821543
# assesstot%        0.821424
# sanitdistrict%    0.565764
# ext%              0.527255
# residfar%         0.437605
# ownername%        0.305397
# yearalter1%       0.105968
# schooldist%       0.087399
# appdate%          0.080464
# address%          0.036453
# yearalter2%       0.017961
# builtfar%         0.014599
# numfloors%        0.013098
# yearbuilt%        0.012154
# lotarea%          0.011005
# lotfront%         0.010416
# lotdepth%         0.010234
# bldgdepth%        0.010053
# bldgfront%        0.008205
# Name: 0, dtype: float64

# %%
results0 = pd.read_csv('results_18v1_18v2.csv', index_col = False)

# %%
plt.figure(figsize=(6, 30))
plt.plot(results_df.iloc[0, :], range(96), label = '18v2_19v1', color = 'blue')
plt.plot(results0.iloc[0, :], range(87), label = '18v1_18v2', color = 'red')
label = list(results_df.iloc[0, :])
label0 = list(results0.iloc[0, :])

for i in range(len(label)):
    if label[i] >= 0.1:
        plt.text(x = label[i] , y = i-0.15, s = '{}%'.format(np.round(label[i]*100, 2)), size = 10, color = 'blue')
    else: 
        pass
    
for i in range(len(label0)):
    if label0[i] >= 0.1:
        plt.text(x = label0[i] , y = i-0.15, s = '{}%'.format(np.round(label0[i]*100, 2)), size = 10, color = 'red')
    else: 
        pass
    
plt.yticks(range(96), results_df.columns, rotation='horizontal')
plt.legend()
plt.title('19v1_18v2_18v1_pct_mismatch_comparison')
plt.savefig('19v1_18v2_18v1_pct_mismatch_comparison.png', bbox_inches='tight')
plt.show()
